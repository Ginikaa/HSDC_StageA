# %% [markdown]
# ## Hamoye Data Science Internship Stage A
# These codes were used to derive the answers to the Hamoye Data Science Internship Quiz for the "Introduction to Python for Machine Learning" course.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('http://bit.ly/HDSC-Dataset')
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %% [markdown]
# Which of the following fuel type code has the lowest average fuel cost per unit burned? As seen below, the type code with the lowest average fuel cost per unit burned is gas.

# %%
df[['fuel_type_code_pudl', 'fuel_cost_per_unit_burned']].groupby(['fuel_type_code_pudl']).mean()
# Out:
#                      fuel_cost_per_unit_burned
# fuel_type_code_pudl
# coal                                 67.421830
# gas                                  13.659397
# nuclear                            4955.157002
# oil                                 168.877086
# other                                18.253856
# waste                                19.518122

# %% [markdown]
# What is the standard deviation and 75th percentile of the measure of energy per unit (Fuel_mmbtu_per_unit) in two decimal places? This is derived by using the describe method.

# %%
df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %% [markdown]
# What is the skewness and kurtosis for the fuel quantity burned in two decimal places?\
# skewness = 15.85

# %%
skew = df.skew(axis = 0)
skew
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %% [markdown]
# What is the skewness and kurtosis for the fuel quantity burned in two decimal places?\
# kurtosis = 651.37

# %%
kurtosis = df.kurtosis(axis = 0)
kurtosis
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %% [markdown]
# Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places?\
# Feature:fuel_unit

# %%
df.isnull().any()
# Out:
# record_id                       False
# utility_id_ferc1                False
# report_year                     False
# plant_name_ferc1                False
# fuel_type_code_pudl             False
# fuel_unit                        True
# fuel_qty_burned                 False
# fuel_mmbtu_per_unit             False
# fuel_cost_per_unit_burned       False
# fuel_cost_per_unit_delivered    False
# fuel_cost_per_mmbtu             False
# dtype: bool

# %% [markdown]
# Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places?\
# Total:180

# %%
missingvalues_count = df.isnull().sum()
missingvalues_count
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29523, step=1)

# %%
len(df.index)
# Out:
# 29523

# %% [markdown]
# Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places?\
# Percent:0.610

# %%
percent = (180/len(df.index))*100
percent
# Out:
# 0.609694136774718

# %% [markdown]
# Fuel_unit is a categorical variable

# %%
df.groupby('fuel_unit').count()
# Out:
#            record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# fuel_unit
# bbl             7998              7998         7998              7998
# gal               84                84           84                84
# gramsU           464               464          464               464
# kgU              110               110          110               110
# mcf            11354             11354        11354             11354
# mmbtu            180               180          180               180
# mwdth             95                95           95                95
# mwhth            100               100          100               100
# ton             8958              8958         8958              8958
#
#            fuel_type_code_pudl  fuel_qty_burned  fuel_mmbtu_per_unit  \
# fuel_unit
# bbl                       7998             7998                 7998
# gal                         84               84                   84
# ...

# %% [markdown]
# Which of the features has the second and third lowest correlation with the Fuel Cost Per Unit Burned?\
# fuel_qty_burned and fuel_mmbtu_per_unit

# %%
df.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %% [markdown]
# Which year has the highest average fuel cost per unit delivered?\
# 1997

# %%
new = df.iloc[:,[2,9]]
new.groupby(['report_year']).mean()
# Out:
#              fuel_cost_per_unit_delivered
# report_year
# 1994                            63.636060
# 1995                            32.735269
# 1996                          9196.705948
# 1997                         11140.197239
# 1998                           287.154420
# 1999                            25.551627
# 2000                           985.362877
# 2001                            60.050396
# 2002                            47.594361
# 2003                            55.663493
# 2004                           139.524275
# 2005                            41.438184
# 2006                            38.657484
# 2007                            43.325023
# 2008                            58.588197
# 2009                           652.694163
# 2010                            91.862105
# 2011                            59.774667
# 2012                            60.994502
# 2013                           172.307591
# 2014                           192.737183
# ...

# %% [markdown]
# Which year has the highest average fuel cost per unit delivered?\
# 1997

# %%
new = df.iloc[:,[2,9]]
new.groupby(['report_year']).mean().idxmax()
# Out:
# fuel_cost_per_unit_delivered    1997
# dtype: int64

# %%
df_new = df.iloc[:,[4,2,6]]
df_new_coal = df_new.loc[(df_new["fuel_type_code_pudl"] == "coal") & ((df_new["report_year"] == 1994) | (df_new["report_year"] == 1998))]
df_new_coal.groupby(['report_year']).mean()
# Out:
#              fuel_qty_burned
# report_year
# 1994            1.509912e+06
# 1998            2.084013e+06
